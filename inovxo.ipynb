# %%
import pandas as pd
import re
import numpy as np

# %%
df=pd.read_csv("C:/Users/ADMIN/Downloads/Innovox-Audio-Pricing-All-Levels-March-2021.csv",delimiter=',', names=list(range(10)))

# %%
df

# %%
df.dropna(thresh=4,inplace=True)

# %%
df.dropna(axis=1,how='all',inplace=True)

# %%
df.columns=df.iloc[0]

# %%
df

# %%
df1 = pd.DataFrame(df, index=range(27,75))

# %%
df

# %%
df1.dropna(thresh=4, inplace=True)

# %%
df1.dropna(axis=1, how='all', inplace=True)

# %%
df1

# %%
Premium -5%

# %%
df1["Premium -5% "] = df1["Premium -5% "].fillna('-')

# %%
df1 = df1[df1["Premium -5% "].str.match('[^a-zA-Z]')]

# %%
df1["Premium -5% "]=df1["Premium -5% "].replace("-", "", regex=True)

# %%
df1

# %%
df2 = pd.DataFrame(df, index=range(76, 82))

# %%
df2

# %%
df2.columns=df2.iloc[0]

# %%
df2

# %%
df2
# Out:
# 76     Model        Category                                     Description  \
# 77  SHMF-1WM      SPKR FRAME      Slim single display frame 3.50" D 9.00" H
# 78  SHMF-2WM      SPKR FRAME        Slim dual display frame 3.50" D 9.00" H
# 79     SSCMP   CAMERA POCKET   Sliding camera pocket module for slim frames
# 80    SMSM-6            SPKR            Single 6" subwoofer for slim frames
# 81  SMSM-2x6            SPKR              Dual 6" subwoofer for slim frames
#
# 76    MSRP  Std. Dealer  Value -3%  Premium -5%  Partner -10%
# 77  $1,097         $658       $638         $625          $592
# 78  $1,372         $823       $798         $782          $741
# 79    $463         $278       $270         $264          $250
# 80    $512         $307       $298         $292          $276
# 81    $862         $517       $501         $491          $465

# %%
df2['Description'] = df2[2] + df2[3]

# %%
df2[2] = df2[2].fillna('Description')

# %%
df2.dropna(axis=1,thresh=2,inplace=True)

# %%
df2

# %%
df2 = df2[df2["MSRP "].str.match('[^a-zA-Z]')]

# %%
df2

# %%
df3 = pd.DataFrame(df, index=range(82, 102))

# %%
df3
# Out:
# 83                 Model   Display Size   \
# 84       Synergy Compact        49" 75"
# 85   Synergy Compact T-M             NaN
# 86    Flex Companion 2x5   LF Extension
# 87    Flex Companion 2x6   LF Extension
# 90             FPH1 3250        32' 50'
# 91             FPH1 5070        50" 70"
# 92             FPH1 7585        75" 85'
# 93             FPH2 3250      32" - 50'
# 94             FPH2 5070        50' 70"
# 95             FPH2 7585      75" - 85"
# 96             FPH3 7585        75" 85'
# 99             FPV2 3250        32' 50"
# 100            FPV2 5070        50" 70"
# 101            FPV2 7585        75" 85"
#
# 83                                        Description     MSRP  Std. Dealer   \
# 84   Huddle & Collaboration Space Solution. featuri...  $2,647       $1,588
# 85   Huddle & Collaboration Space Solution, featuri...  $3,009       $1,805
# 86   2x5" 200W powered subwoofer for use with Syner...  $1,061         $636
# ...

# %%
df3.isnull().sum()
# Out:
# 83
# Model            0
# Display Size     1
# Description      6
# MSRP             0
# Std. Dealer      0
# Value -3%        0
# Premium -5%      0
# Partner -10%     0
# dtype: int64

# %%
df3.dropna(thresh=2,inplace=True)

# %%
df3.dropna(axis=1,how='all', inplace=True)

# %%
df3.columns=df3.iloc[0]

# %%
df3

# %%
df3 = df3[df3["MSRP "].str.match('[^a-zA-Z]')]

# %%
df3

# %%
df4 = pd.DataFrame(df, index=range(102, 106))

# %%
df4.dropna(thresh=2,inplace=True)

# %%
df4.dropna(axis=1,how='all', inplace=True)

# %%
df4.columns=df4.iloc[1]

# %%
df4 = df4[df4["MSRP "].str.match('[^a-zA-Z]')]

# %%
df4["MSRP "]=df4["MSRP "].fillna("-")

# %%
df4
# Out:
# 103          Model        Catagory   NaN                        Description   \
# 102  FlexPrecision   Power Options    /   Low-Frequency extension / Options
# 104         Flex P       Amplifier   NaN         2x200W Class D amplifier *
# 105        Flex PX       Amplifier   NaN     2x200W Class D amplifier w/DSP
#
# 103    MSRP  Std. Dealer  Value -3%  Premium -5%  Partner -10%
# 102        -          NaN        NaN          NaN           NaN
# 104    $590         $354       $343         $336          $319
# 105  $1,278         $767       $744         $729          $690

# %%
df5 = pd.DataFrame(df, index=range(108, 110))

# %%
df5.dropna(thresh=2,inplace=True)

# %%
df5.dropna(axis=1,how='all', inplace=True)

# %%
df5.columns=df5.iloc[0]

# %%
df5 = df5[df5["MSRP "].str.match('[^a-zA-Z]')]

# %%
df5
# Out:
# 108                    Model Display Size Description   MSRP   \
# 109  FSH2 3265 32" 65' 2 channel horizontal video d...  $905
#
# 108 Std Dealer Value -3%  Premium -5%  Partner -10%
# 109            $543 $527         $516          $489

# %%
df6 = pd.DataFrame(df, index=range(111, 123))

# %%
df6.dropna(thresh=2,inplace=True)

# %%
df6.dropna(axis=1,how='all', inplace=True)

# %%
df6.columns=df6.iloc[0]

# %%
df6 = df6[df6["MSRP "].str.match('[^a-zA-Z]')]

# %%
df6
# Out:
# 111             Model     Display Size   \
# 112         FSV2 3265          32' 65'
# 115      FFH1.25 5070          50' 70'
# 116      FFH1 25 7085          70" 85"
# 117     FFH1 .25 8698          86" 98'
# 118   FFH1.25 98 Plus   98" and larger
# 119     FFH1 .50 5070          50' 70'
# 120     FFH1.50 07085          70" 85'
# 121      FFH1.50 8698          86" 98'
# 122  FFH1 .50 98 Plus   98" and larger
#
# 111                                       Description     MSRP  Std Dealer   \
# 112  2 channel vertical video display loudspeaker n...  $1,187        $712
# 115  1 channel horizontal line array video display ...  $1,020        $612
# 116                                                NaN  $1,255        $753
# 117                                                NaN  $1,372        $823
# 118                                                NaN  $1,628        $977
# 119  1 channel horizontal line array video display ...  $1,020        $612
# ...

# %%
df7 = pd.DataFrame(df, index=range(123, 129))

# %%
df7.dropna(thresh=2,inplace=True)

# %%
df7.dropna(axis=1,how='all', inplace=True)

# %%
df7.columns=df7.iloc[0]

# %%
df7 = df7[df7["Value -3% "].str.match('[^a-zA-Z]')]

# %%
df7
# Out:
# 124         Model                           Display Size Description   \
# 125     FFV2 5070   50" 70" 2 channel vertical line array video di...
# 126     FFV2 7085                                          70" - 85"
# 127     FFV2 8698                                          86" - 98"
# 128  FFV2 98 Plus                                     98" and larger
#
# 124 MSRP Std   Dealer  Value -3%  Premium -5%  Partner -10%
# 125   $1,995   $1,197     $1,161       $1,137        $1,077
# 126   $2,328   $1,397     $1,355       $1,327        $1,257
# 127   $2,662   $1,597     $1,549       $1,517        $1,437
# 128   $2,995   $1,797     $1,743       $1,707        $1,617

# %%
df8 = pd.DataFrame(df, index=range(129, 134))

# %%
df8.dropna(thresh=2,inplace=True)

# %%
df8.dropna(axis=1,how='all', inplace=True)

# %%
df8.columns=df8.iloc[0]

# %%
df8 = df8[df8["Value -3% "].str.match('[^a-zA-Z]')]

# %%
df8
# Out:
# 130     Model    Catagory       NaN                         Description   \
# 131    Flex P   Amplifier   2x200W                  Class D amplifier *
# 132   Flex PX   Amplifier   2x200W              Class D amplifier w/DSP
# 133  Flex PXD   Amplifier   2x200W   Class D amplifier w/DSP & Dante **
#
# 130    MSRP  Std Dealer  Value -3%  Premium -5%  Partner -10%
# 131    $590        $354       $343         $336          $319
# 132  $1,278        $767       $744         $729          $690
# 133  $1,658        $995       $965         $945          $896

# %%
df9 = pd.DataFrame(df, index=range(134, 137))

# %%
df9.dropna(thresh=2,inplace=True)

# %%
df9.dropna(axis=1,how='all', inplace=True)

# %%
df9.columns=df9.iloc[0]

# %%
df9 = df9[df9["Value -3% "].str.match('[^a-zA-Z]')]

# %%
df9
# Out:
# 134              Model  Category   \
# 135          FlexArray      SPKR
# 136  FlexArray Compact      SPKR
#
# 134                                       Description      MSRP  Std Dealer   \
# 135  Large powered line array, with steered dipole ...  $27,987     $16,792
# 136  Compact powered line array, with steered dipol...  $14,295      $8,577
#
# 134 Value -3%  Premium -5%  Partner -10%
# 135   $16,288      $15,952       $15,113
# 136    $8,320       $8,148        $7,719

# %%
df10 = pd.DataFrame(df, index=range(144, 465))

# %%
df10.dropna(thresh=2,inplace=True)

# %%
df10.dropna(axis=1,how='all', inplace=True)

# %%
df10.columns=df10.iloc[0]

# %%
df10 = df10[df10["Value -3% "].str.match('[^a-zA-Z]')]

# %%
df10
# Out:
# 148               Model       Catagory   \
# 149  Flex Companion 2x5   LF Extension
# 150  Flex Companion 2x6   LF Extension
# 152         CLA-935 blk           SPKR
# 153         CLA-935 wht           SPKR
# 154         CLA-950 blk           SPKR
# ..                   ...            ...
# 460         SCS-318 blk        CRD SUB
# 461         SCS-318 wht        CRD SUB
# 462         SCS-318 cst        CRD SUB
# 463         SCS-321 blk        CRD SUB
# 464         SCS-321 wht        CRD SUB
#
# 148                                       Description      MSRP  Std Dealer   \
# 149  2x5" 200W powered low-frequency extension, sur...   $1,060        $636
# 150  2x6" 200W powered low-frequency extension, sur...   $1,112        $667
# 152                   x3.5" mid, 9 ribbon HF 120Hx35V    $2,643      $1,586
# 153                9 x 3.5" mid, 9 ribbon HF 120Hx35V    $2,643      $1,586
# 154                   x3.5" mid, 9 ribbon HF 120Hx50V    $2,643      $1,586
# ...

# %%
df11 = pd.DataFrame(df, index=range(465, 501))

# %%
df11.dropna(thresh=2,inplace=True)

# %%
df11.dropna(axis=1,how='all', inplace=True)

# %%
df11.columns=df11.iloc[0]

# %%
df11 = df11[df11["Value -3% "].str.match('[^a-zA-Z]')]

# %%
df11
# Out:
# 465        Model  Category   \
# 466   SLF112 blk       SUB
# 467   SLF112 wht       SUB
# 468   SLF112 cst       SUB
# 469  SLF112P blk       SUB
# 470  SLF112P wht       SUB
# 471  SLF112P cst       SUB
# 472   SLF212 blk       SUB
# 473   SLF212 wht       SUB
# 474   SLF212 cst       SUB
# 475  SLF212P blk       SUB
# 476  SLF212P wht       SUB
# 477  SLF212P cst       SUB
# 478   SLF115 blk       SUB
# 479   SLF115 wht       SUB
# 480   SLF115 cst       SUB
# 481  SLF115P blk       SUB
# 482  SLF115P wht       SUB
# 483  SLF115P cst       SUB
# 484   SLF215 blk       SUB
# 485   SLF215 wht       SUB
# 486   SLF215 cst       SUB
# 487  SLF215P blk       SUB
# 488  SLF215P wht       SUB
# 489  SLF215P cst       SUB
# 490   SLF118 blk       SUB
# 491   SLF118 wht       SUB
# 492   SLF118 cst       SUB
# 493  SLF118P blk       SUB
# 494  SLF118P wht       SUB
# 495  SLF118P cst       SUB
# 496   SLF218 blk       SUB
# 497   SLF218 wht       SUB
# 498   SLF218 cst       SUB
# ...

# %%
df12 = pd.DataFrame(df, index=range(501, 524))

# %%
df12.dropna(thresh=2,inplace=True)

# %%
df12.dropna(axis=1,how='all', inplace=True)

# %%
df12.columns=df12.iloc[0]

# %%
df12 = df12[df12["Value -3% "].str.match('[^a-zA-Z]')]

# %%
df12.columns=df12.iloc[12]

# %%
df12
# Out:
# 514 Dual woofer designs  available Category   \
# 502          SB-115 blk                 SUB
# 503          SB-115 wht                 SUB
# 504          SB-115 cst                 SUB
# 505          SB-118 blk                 SUB
# 506          SB-118 wht                 SUB
# 507          SB-118 cst                 SUB
# 508        SB-115PA blk                 SUB
# 509        SB-115PA wht                 SUB
# 510        SB-115PA cst                 SUB
# 511        SB-118PA blk                 SUB
# 512        SB-118PA wht                 SUB
# 513        SB-118PA cst                 SUB
# 515         SBA-115 blk                 SUB
# 516         SBA-115 wht                 SUB
# 517         SBA-115 cst                 SUB
# 518         SBA-118 blk                 SUB
# 519         SBA-118 wht                 SUB
# 520         SBA-118 cst                 SUB
# 521         SBA-218 blk                 SUB
# 522         SBA-218 wht                 SUB
# ...

# %%
df13 = pd.DataFrame(df, index=range(524, 543))

# %%
df13.dropna(thresh=2,inplace=True)

# %%
df13.dropna(axis=1,how='all', inplace=True)

# %%
df13.columns=df13.iloc[0]

# %%
df13 = df13[df13["Value -3% "].str.match('[^a-zA-Z]')]

# %%
df13
# Out:
#                         0          1                                        2  \
# 524                Model   Category                                       NaN
# 525   HLA-SBA-16 F/B blk        ACC       Fly hardware SBA-115 behind HLA-16
# 526   HLA-SBA-16 F/B wht        ACC       Fly hardware SBA-115 behind HLA-16
# 527   HLA-SBA-16 F/B cst        ACC       Fly hardware SBA-115 behind HLA-16
# 528   HLA-SBA-16 T/B blk        ACC        Fly hardware HLA-16 below SBA-115
# 529   HLA-SBA-16 T/B wht        ACC        Fly hardware HLA-16 below SBA-115
# 530   HLA-SBA-16 T/B cst        ACC        Fly hardware HLA-16 below SBA-115
# 531   HLA-SBA-20 F/B blk        ACC       Fly hardware SBA-118 behind HLA-20
# 532   HLA-SBA-20 F/B wht        ACC       Fly hardware SBA-118 behind HLA-20
# 533   HLA-SBA-20 F/B cst        ACC       Fly hardware SBA-118 behind HLA-20
# 534   HLA-SBA-20 T/B blk        ACC        Fly hardware HLA-20 below SBA-118
# ...

# %%
df14 = pd.DataFrame(df, index=range(543, 590))

# %%
df14.dropna(thresh=2,inplace=True)

# %%
df14.dropna(axis=1,how='all', inplace=True)

# %%
df14.columns=df14.iloc[0]

# %%
df14 = df14[df14["Dealer Value "].str.match('[^a-zA-Z]')]

# %%
df14
# Out:
# 543                         Model  Category   \
# 544                          CA-2       AMP
# 545                  X8 DSP+DANTE       AMP
# 546                    X8 DSP+ETH       AMP
# 547                  X4 DSP+DANTE       AMP
# 548                    X4 DSP+ETH       AMP
# 549                 X4L DSP+DANTE       AMP
# 550                   X4L DSP+ETH       AMP
# 551      Duecanali 6404 DSP+DANTE       AMP
# 552      Duecanali 4804 DSP+DANTE       AMP
# 553                Duecanali 4804       AMP
# 554      Duecanali 1604 DSP+DANTE       AMP
# 555                Duecanali 1604       AMP
# 556       Duecanali 804 DSP+DANTE       AMP
# 557                 Duecanali 804       AMP
# 558  Quattrocanali 8804 DSP+DANTE       AMP
# 559  Quattrocanali 4804 DSP+DANTE       AMP
# 560            Quattrocanali 4804       AMP
# 561  Quattrocanali 2404 DSP+DANTE       AMP
# 562            Quattrocanali 2404       AMP
# 563  Quattrocanali 1204 DSP+DANTE       AMP
# ...
